# %% [markdown]
# maybe i have to design something like this instead of the homogeneous reactor?
#
# ![image.png](attachment:image.png)

# %% [markdown]
# fuel would be natural uranium
# instead of sodium we'd have D2O
# instead of helium we'd have D2O
# maximizing pins so we have more 'lattice' is better
# simulation in openmc to get k_eff slightly supercritical
# export 2 group coefficients
# diffusion simulation to fine tune control rods
